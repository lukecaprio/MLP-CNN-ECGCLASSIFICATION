# %% [markdown]
# ### Build a DNN for ECG Signal Classification (5 classes)  - Pytorch
# This is the implementation of an MLP for classifying the ECG signals. <br>

# %%
#LUKE CAPRIO

# %%
import os
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as nnF
from torch.utils.data import DataLoader as torch_dataloader
from torch.utils.data import Dataset as torch_dataset
import torch.optim as optim

# %% [markdown]
# ## The Neural Network: MLP

# %%
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.linear1 = nn.Linear(in_features=187, out_features=256)
        
        self.linear2 = nn.Linear(256, 256)
        
        self.norm3 = nn.BatchNorm1d(256)
        self.linear3 = nn.Linear(256, 256)
  
        self.norm4 = nn.BatchNorm1d(256)
        self.linear4 = nn.Linear(256, 256)
        
        self.norm5 = nn.BatchNorm1d(256)
        self.linear5 = nn.Linear(256, 256)

        self.linear6 = nn.Linear(256, 5)
        
    def forward(self, x):
        
        x=nnF.relu(self.linear1(x))
        
        x=nnF.relu(self.linear2(x))
        
        x = self.norm3(x)
        x=nnF.relu(self.linear3(x))
        
        x = self.norm4(x)
        x=nnF.relu(self.linear4(x))
        
        x = self.norm5(x)
        x=nnF.relu(self.linear5(x))
        
        
        z=self.linear6(x)
        #y=nnF.softmax(z, dim=1)
        return z

# %%
model=Net()
x=torch.rand(10,187) # if network is MLP
#x=torch.rand(10,1,187) if network is CNN
z=model(x)

# %%
def save_checkpoint(filename, model, optimizer, result, epoch):
    torch.save({'epoch': epoch,
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'result':result},
               filename)
    print('saved:', filename)

# %%
def cal_accuracy(confusion):
    #input: confusion is the confusion matrix
    #output: acc is the standard classification accuracy
    M=confusion.copy().astype('float32')
    acc = M.diagonal().sum()/M.sum()    
    sens=np.zeros(M.shape[0])
    prec=np.zeros(M.shape[0]) 
    for n in range(0, M.shape[0]):
        TP=M[n,n]
        FN=np.sum(M[n,:])-TP
        FP=np.sum(M[:,n])-TP
        sens[n]=TP/(TP+FN)
        prec[n]=TP/(TP+FP)       
    return acc, sens, prec

# %% [markdown]
# ## The function to train the model

# %%
def train(model, device, optimizer, dataloader, epoch):    
    model.train()#set model to training mode
    loss_train=0
    acc_train =0 
    sample_count=0
    for batch_idx, (X, Y) in enumerate(dataloader):
        X, Y = X.to(device), Y.to(device)
        optimizer.zero_grad()#clear grad of each parameter
        Z = model(X)#forward pass
        loss = nnF.cross_entropy(Z, Y)
        loss.backward()#backward pass
        optimizer.step()#update parameters
        loss_train+=loss.item()
        #do not need softmax
        Yp = Z.data.max(dim=1)[1]  # get the index of the max               
        acc_train+= torch.sum(Yp==Y).item()
        sample_count+=X.size(0)
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{:.0f}%]\tLoss: {:.6f}'.format(
                    epoch, 100. * batch_idx / len(dataloader), loss.item()))
    loss_train/=len(dataloader)
    #due to upsampling, len(dataloader.dataset) != sample_count
    #acc_train/=len(dataloader.dataset) 
    acc_train/=sample_count    
    return loss_train, acc_train

# %% [markdown]
# ## The Function to test the model

# %%
def test(model, device, dataloader):
    model.eval()#set model to evaluation mode
    acc_test =0
    confusion=np.zeros((5,5))
    with torch.no_grad(): # tell Pytorch not to build graph in the with section
        for batch_idx, (X, Y) in enumerate(dataloader):
            X, Y = X.to(device), Y.to(device)
            Z = model(X)#forward pass
            #do not need softmax
            Yp = Z.data.max(dim=1)[1]  # get the index of the max 
            acc_test+= torch.sum(Yp==Y).item()
            for i in range(0, 5):
                for j in range(0, 5):
                    confusion[i,j]+=torch.sum((Y==i)&(Yp==j)).item()
    acc, sens, prec=cal_accuracy(confusion)
    return acc, (confusion, sens, prec)

# %% [markdown]
# ## Load data and create dataloaders

# %%
class MyDataset(torch_dataset):
    def __init__(self, X, Y):
        self.X=X
        self.Y=Y
    def __len__(self):
        #return the number of data points
        return self.X.shape[0]
    def __getitem__(self, idx):        
        #we can use DatasetName[idx] to get a data point (x,y) with index idx
        x=torch.tensor(self.X[idx], dtype=torch.float32)
        y=torch.tensor(self.Y[idx], dtype=torch.int64)
        #x=x.reshape(1,-1) if network is CNN
        return x, y

# %%
import pandas as pd
X=pd.read_csv('ECG_dataX.csv')
Y=pd.read_csv('ECG_dataY.csv')

# %%
#convert dataframe to numpy array
X=X.values
X.shape
# Out:
# (3841, 187)

# %%
#convert dataframe to numpy array
Y=Y.values
Y.shape
# Out:
# (3841, 1)

# %%
#reshape Y into a 1D array
Y=Y.reshape(-1)
Y.shape
# Out:
# (3841,)

# %%
plt.hist(Y)
# Out:
# (array([800.,   0., 800.,   0.,   0., 800.,   0., 641.,   0., 800.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
fs=125  # sampling frequency
Ts=1/fs # sampling interval
N=187 # the number of timepoints
Duration=N*Ts # duration of a signal
t=np.linspace(0, Duration-Ts, N) # array of timepoints
fig, ax = plt.subplots(5,1,constrained_layout=True, figsize=(10,10))
for c in range(0, 5):   
    for n in range(0, 3):
        idx=np.random.randint(0,10)
        ax[c].plot(t, X[Y==c][idx])        
        ax[c].set_xlabel('time t [seconds]', fontsize=16)
        ax[c].set_ylabel('amplitude', fontsize=16)
    ax[c].set_title('class '+str(c), fontsize=16)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=0)
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.1, random_state=0)

# %%
dataset_train=MyDataset(X_train, Y_train)
dataset_val=MyDataset(X_val, Y_val)
dataset_test=MyDataset(X_test, Y_test)

# %%
loader_train = torch_dataloader(dataset_train, batch_size=128, shuffle=True, num_workers=0)
loader_val = torch_dataloader(dataset_val, batch_size=128, shuffle=False, num_workers=0) 
loader_test = torch_dataloader(dataset_test, batch_size=128, shuffle=False, num_workers=0)

# %% [markdown]
# ## Create a model, and start the traning-validation-testing process

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model=Net()
model.to(device)
# Out:
# Net(
#   (linear1): Linear(in_features=187, out_features=256, bias=True)
#   (linear2): Linear(in_features=256, out_features=256, bias=True)
#   (norm3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear3): Linear(in_features=256, out_features=256, bias=True)
#   (norm4): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear4): Linear(in_features=256, out_features=256, bias=True)
#   (norm5): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (linear5): Linear(in_features=256, out_features=256, bias=True)
#   (linear6): Linear(in_features=256, out_features=5, bias=True)
# )

# %% [markdown]
# use stochastic gradient descent as the optimization method

# %%
optimizer = optim.Adamax(model.parameters(), lr=0.001, weight_decay=1e-4)

# %%
loss_train_list=[]
acc_train_list=[]
acc_val_list=[]
epoch_save=-1

# %% [markdown]
# train/val/test over many epochs

# %%
for epoch in range(epoch_save+1, 100): #change 100 to a larger number if necessary
    #-------- training --------------------------------
    loss_train, acc_train =train(model, device, optimizer, loader_train, epoch)    
    loss_train_list.append(loss_train)
    acc_train_list.append(acc_train)
    print('epoch', epoch, 'training loss:', loss_train, 'acc:', acc_train)
    #-------- validation --------------------------------
    acc_val, other_val = test(model, device, loader_val)
    acc_val_list.append(acc_val)
    print('epoch', epoch, 'validation acc:', acc_val)
    #--------save model-------------------------
    result = (loss_train_list, acc_train_list, 
              acc_val_list, other_val)
    save_checkpoint('LUKECAPRIO_ECG_MLP_Pytorch_epoch'+str(epoch)+'.pt', model, optimizer, result, epoch)
    epoch_save=epoch
# Out:
# Train Epoch: 0 [0%]	Loss: 1.635465
# epoch 0 training loss: 0.8710527745160189 acc: 0.695369030390738
# epoch 0 validation acc: 0.46753246
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epo
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch89.pt
# Train Epoch: 90 [0%]	Loss: 0.001436
# epoch 90 training loss: 0.009043881775472652 acc: 0.998191027496382
# epoch 90 validation acc: 0.8474026
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch90.pt
# Train Epoch: 91 [0%]	Loss: 0.002176
# epoch 91 training loss: 0.006786295305408368 acc: 0.9996382054992764
# epoch 91 validation acc: 0.8603896
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch91.pt
# Train Epoch: 92 [0%]	Loss: 0.001418
# epoch 92 training loss: 0.0031985190375549296 acc: 0.9992764109985528
# epoch 92 validation acc: 0.8733766
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch92.pt
# Train Epoch: 93 [0%]	Loss: 0.003912
# epoch 93 training loss: 0.006270481839733707 acc: 0.9989146164978292
# epoch 93 validation acc: 0.8733766
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch93.pt
# Train Epoch: 94 [0%]	Loss: 0.000643
# epoch 94 training loss: 0.003129512213159945 acc: 0.9985528219971056
# epoch 94 validation acc: 0.8701299
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch94.pt
# Train Epoch: 95 [0%]	Loss: 0.000902
# epoch 95 training loss: 0.003316131708826023 acc: 0.9989146164978292
# epoch 95 validation acc: 0.8603896
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch95.pt
# Train Epoch: 96 [0%]	Loss: 0.001047
# epoch 96 training loss: 0.005408759021189657 acc: 0.9989146164978292
# epoch 96 validation acc: 0.8766234
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch96.pt
# Train Epoch: 97 [0%]	Loss: 0.000423
# epoch 97 training loss: 0.0033633455128768796 acc: 0.9992764109985528
# epoch 97 validation acc: 0.8766234
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch97.pt
# Train Epoch: 98 [0%]	Loss: 0.000544
# epoch 98 training loss: 0.0030731177777686917 acc: 0.9989146164978292
# epoch 98 validation acc: 0.8831169
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch98.pt
# Train Epoch: 99 [0%]	Loss: 0.000284
# epoch 99 training loss: 0.0025525031444637784 acc: 0.9996382054992764
# epoch 99 validation acc: 0.8668831
# saved: LUKECAPRIO_ECG_MLP_Pytorch_epoch99.pt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12,6))
ax[0].set_title('loss v.s. epoch',fontsize=16)
ax[0].plot(loss_train_list, '-b', label='training loss')
ax[0].set_xlabel('epoch',fontsize=16)
ax[0].legend(fontsize=16)
ax[0].grid(True)
ax[1].set_title('accuracy v.s. epoch',fontsize=16)
ax[1].plot(acc_train_list, '-b', label='training accuracy')
ax[1].plot(acc_val_list, '-g', label='validation accuracy')
ax[1].set_xlabel('epoch',fontsize=16)
ax[1].legend(fontsize=16)
ax[1].grid(True)

# %% [markdown]
# load the best model

# %%
best_epoch=np.argmax(acc_val_list)
best_epoch
# Out:
# 98

# %%
checkpoint=torch.load('LUKECAPRIO_ECG_MLP_Pytorch_epoch'+str(best_epoch)+'.pt')
model=Net()
model.load_state_dict(checkpoint['model_state_dict'])
model.to(device);
model.eval();

# %%
acc, (confusion, sens, prec) = test(model, device, loader_test)
print('Accuracy (average)', acc)
print('Sensitivity', sens)
print('Precision', prec)
print('Confusion \n', confusion)
# Out:
# Accuracy (average) 0.8855657
# Sensitivity [0.82954544 0.87012988 0.87671232 0.93442625 0.92982459]
# Precision [0.82954544 0.8427673  0.92753625 0.85074627 0.98148149]
# Confusion
#  [[146.  18.   4.   5.   3.]
#  [ 14. 134.   1.   5.   0.]
#  [  5.   3. 128.  10.   0.]
#  [  6.   0.   2. 114.   0.]
#  [  5.   4.   3.   0. 159.]]
